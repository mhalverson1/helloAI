# %% [markdown]
# <a href="https://colab.research.google.com/github/mhalverson1/helloAI/blob/main/halverson_asg3_hyperparams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://blog.infuseai.io/run-a-full-tty-terminal-in-google-colab-without-colab-pro-2759b9f8a74a
# xterm may be helpful for speeding up some of the parts of this assignment ... see in class instruction on usage
#!pip install colab-xterm
#%load_ext colabxterm
# !git clone "https://github.com/kartoone/nn3"
# !git pull
# Out:
# Cloning into 'nn3'...
# remote: Enumerating objects: 156, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 156 (delta 26), reused 17 (delta 8), pack-reused 109
# Receiving objects: 100% (156/156), 94.35 MiB | 12.72 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# Updating files: 100% (106/106), done.
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %cd nn3/src
# Out:
# /content/nn3/src

# %%
from network import Network
import mnist_loader
import numpy as np
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
net = Network([784, 30, 10])
print(np.shape(net.biases))
print(net.biases)
# Out:
# (2,)
# [array([[ 0.05925965],
#        [-1.21078537],
#        [-0.02337799],
#        [ 0.09826535],
#        [-1.53492472],
#        [ 0.94354231],
#        [ 0.84974885],
#        [ 0.95458049],
#        [-0.4006458 ],
#        [-0.67915556],
#        [-1.93250494],
#        [ 1.7147186 ],
#        [ 1.74454445],
#        [ 0.68204158],
#        [-1.23070526],
#        [-0.479311  ],
#        [-0.53583228],
#        [-0.50048147],
#        [ 1.90788262],
#        [-0.6910547 ],
#        [ 0.00289667],
#        [-1.36198075],
#        [ 1.29357916],
#        [ 0.57773458],
#        [ 2.45065656],
#        [ 2.20222558],
#        [ 1.80009549],
#        [-0.21074161],
#        [-0.79688179],
#        [ 1.57977168]]), array([[-1.10431701],
#        [-1.16154374],
#        [-1.6537557 ],
#        [ 0.38139549],
#        [-0.46684924],
#        [-1.27502306],
#        [ 0.7302263 ],
#        [-1.34572239],
#        [-0.1864638 ],
#        [-0.27585205]])]
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:1970: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape

# %%
import numpy as np

# finds the image that the network has the hardest time classifying
def findTroublesomeImage(test_data, net):
  worsti = -1
  worsta = 1.0
  for i,(x,y) in enumerate(test_data):
    a = net.feedforward(x)
    if np.max(a)<worsta:
      worsta = np.max(a)
      worsti = i
  print(worsta)
  print(worsti)
  return worsti

# %%
  from network import Network
  import mnist_loader
  import time

  training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
  configs = [[784,15,10], [784, 30, 10], [784, 100, 10], [784, 15, 15, 10], ] # ADD THE REMAINING CONFIGS HERE!!!!training_times = []
  training_times = []
  accuracies = []
  for config in configs:
    print(config)
    start = time.time()
    net = Network(config)
    accuracies.append(net.SGD(training_data[0:100], 30, 10, 3.0, test_data=test_data[0:100]))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net)
    import matplotlib.pyplot as plt
# Epoch 11: starting...training completed in 0.05s...measuring accuracy...38 / 100 in 0.01s
# Epoch 12: starting...training completed in 0.04s...measuring accuracy...34 / 100 in 0.03s
# Epoch 13: starting...training completed in 0.04s...measuring accuracy...38 / 100 in 0.02s
# Epoch 14: starting...training completed in 0.06s...measuring accuracy...39 / 100 in 0.03s
# Epoch 15: starting...training completed in 0.05s...measuring accuracy...42 / 100 in 0.02s
# Epoch 16: starting...training completed in 0.04s...measuring accuracy...41 / 100 in 0.01s
# Epoch 17: starting...training completed in 0.04s...measuring accuracy...45 / 100 in 0.02s
# Epoch 18: starting...training completed in 0.05s...measuring accuracy...45 / 100 in 0.01s
# Epoch 19: starting...training completed in 0.05s...measuring accuracy...45 / 100 in 0.01s
# Epoch 20: starting...training completed in 0.02s...measuring accuracy...45 / 100 in 0.01s
# Epoch 21: starting...training completed in 0.02s...measuring accuracy...40 / 100 in 0.01s
# Epoch 22: starting...training completed in 0.03s...measuring accuracy...43 / 100 in 0.01s
# Epoch 23: starting...training completed in 0.02s...measuring accuracy...43 / 100 in 0.01s
# Epoch 24: starting...training completed in 0.02s...measuring accuracy...44 / 100 in 0.01s
# Epoch 25: starting...training completed in 0.02s...measuring accuracy...45 / 100 in 0.01s
# Epoch 26: starting...training completed in 0.05s...measuring accuracy...46 / 100 in 0.02s
# Epoch 27: starting...training completed in 0.02s...measuring accuracy...46 / 100 in 0.01s
# Epoch 28: starting...training completed in 0.04s...measuring accuracy...48 / 100 in 0.01s
# Epoch 29: starting...training completed in 0.02s...measuring accuracy...41 / 100 in 0.01s
# 1.5794179439544678
# 0.10311140691000463
# 35

# %%
print(configs)
print(training_times)
print(accuracies)
# Out:
# [[784, 15, 10], [784, 30, 10], [784, 100, 10], [784, 15, 15, 10]]
# [0.7337784767150879, 0.9348595142364502, 2.844740629196167, 1.5794179439544678]
# [50, 56, 39, 41]

# %%
  from network2 import Network
  from network2 import QuadraticCost
  import mnist_loader
  import time
  import matplotlib.pyplot as plt

  training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
  configs = []
  for epochs in [15, 30, 45, 100]:
    for batchsize in [5, 10, 20, 100]:
      for learningrate in [0.1, 0.5, 1.0, 3.0, 5.0]:
        configs.append([epochs, batchsize, learningrate])

  # only train on small slice (start with 100 ... but then once you have your graphs working ... bump it up to 1000 and re-run)
  training_data = training_data[0:100]
  test_data = test_data[0:100]

  training_times = []
  accuracies = []  
  # note that this will be a GIANT list of training times for each config plus the two cost functions. [time1, time2, time3, time4] ... 
  #  time1 and time2 are both associated with the single hidden layer network and differ in the cost function (time1 - crossentropy, time2-quadratic)
  #  time3 and time4 are both associated with the dual hidden layer network and differ in the cost function (time3 - crossentropy, time4-quadratic)
  # NOTE: once you are happy with the results ... remove the 0:1000 and use the complete training data
  for config in configs:
    print(config, "single hidden layer plus cross-entropy")
    start = time.time()
    net1 = Network([784,15,10]) # cross-entropy cost
    accuracies.append(net1.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net1)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()

    print(config, "single hidden layer plus quadratic")
    start = time.time()
    net1 = Network([784, 15, 10],cost=QuadraticCost) # quadratic cost
    accuracies.append(net1.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net1)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()

    # repeat for the two layer network
    print(config, "dual hidden layers plus cross-entropy")
    start = time.time()
    net2 = Network([784,30,15,10])
    accuracies.append(net2.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net2)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()

    print(config, "dual hidden layers plus quadratic")
    start = time.time()
    net2 = Network([784,30,15, 10],cost=QuadraticCost)
    accuracies.append(net2.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net2)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()
# Out:
# [15, 5, 0.1] single hidden layer plus cross-entropy
# 0.2826972007751465
# 0.14584390080221757
# 59
# [15, 5, 0.1] single hidden layer plus quadratic
# 0.3049581050872803
# 0.15039105977725084
# 86
# [15, 5, 0.1] dual hidden layers plus cross-entropy
# 0.4684295654296875
# 0.1298142984438872
# 41
# [15, 5, 0.1] dual hidden layers plus quadratic
# 0.48576831817626953
# 0.13790978574173315
# 95
# [15, 5, 0.5] single hidden layer plus cross-entropy
# 0.326082706451416
# 0.038322168246491775
# 11
# [15, 5, 0.5] single hidden layer plus quadratic
# 0.2919178009033203
# 0.16656420144517964
# 63
# [15, 5, 0.5] dual hidden layers plus cross-entropy
# 0.4964578151702881
# 0.038982995486890895
# 84
# [15, 5, 0.5] dual hidden layers plus quadratic
# 0.49190449714660645
# 0.13855722711614252
# 85
# [15, 5, 1.0] single hidden layer plus cross-entropy
# 0.26364874839782715
# 0.047430177156488625
# 44
# [15, 5, 1.0] single hidden layer plus quadratic
# 0.31459474563598633
# 0.14318414776802854
# 35
# [15, 5, 1.0] dual hidden layers plus cross-entropy
# 0.48628997802734375
# 0.10033253676850747
# 11
# [15, 5, 1.0] dual hidden layers plus quadratic
# 0.5445866584777832
# 0.1649281867423958
# 49
# [15, 5, 3.0] single hidden layer plus cross-entropy
# 0.6398746967315674
# 0.20728356140649176
# 66
# [15, 5, 3.0] single hidden layer plus quadratic
# 0.7210555076599121
# 0.19563898820729192
# 59
# [15, 5, 3.0] dual hidden layers plus cross-entropy
# 1.0478277206420898
# 0.14835118434590672
# 97
# [15, 5, 3.0] dual hidden layers plus quadratic
# 0.5005712509155273
# 0.07408829445482519
# 63
# [15, 5, 5.0] single hidden layer plus cross-entropy
# 0.24508142471313477
# 0.16143497837684567
# 34
# [15, 5, 5.0] single hidden layer plus quadratic
# 0.2965090274810791
# 0.08454358106208171
# 66
# [15, 5, 5.0] dual hidden layers plus cross-entropy
# 0.4429283142089844
# 0.19310036739872455
# 8
# [15, 5, 5.0] dual hidden layers plus quadratic
# 0.5041930675506592
# 0.18294391566227358
# 35
# [15, 10, 0.1] single hidden layer plus cross-entropy
# 0.2524600028991699
# 0.11884449468051983
# 66
# [15, 10, 0.1] single hidden layer plus quadratic
# 0.3182411193847656
# 0.13158527808180875
# 68
# [15, 10, 0.1] dual hidden layers plus cross-entropy
# 0.4408876895904541
# 0.13226711726124182
# 48
# [15, 10, 0.1] dual hidden layers plus quadratic
# 0.48063206672668457
# 0.14110056547716554
# 48
# [15, 10, 0.5] single hidden layer plus cross-entropy
# 0.25848817825317383
# 0.11508525727743743
# 23
# [15, 10, 0.5] single hidden layer plus quadratic
# 0.3143305778503418
# 0.15647489246742044
# 62
# [15, 10, 0.5] dual hidden layers plus cross-entropy
# 0.4263460636138916
# 0.08353094802344799
# 11
# [15, 10, 0.5] dual hidden layers plus quadratic
# 0.46307802200317383
# 0.1349325555432495
# 48
# [15, 10, 1.0] single hidden layer plus cross-entropy
# 0.2772338390350342
# 0.09854224138231478
# 59
# [15, 10, 1.0] single hidden layer plus quadratic
# 0.2766106128692627
# 0.1360194248938788
# 63
# [15, 10, 1.0] dual hidden layers plus cross-entropy
# 0.4684274196624756
# 0.10983223770214512
# 63
# [15, 10, 1.0] dual hidden layers plus quadratic
# 0.45468997955322266
# 0.13926271765836526
# 93
# [15, 10, 3.0] single hidden layer plus cross-entropy
# 0.28191471099853516
# 0.07597312174571576
# 8
# [15, 10, 3.0] single hidden layer plus quadratic
# 0.643897294998169
# 0.15179993369838074
# 47
# [15, 10, 3.0] dual hidden layers plus cross-entropy
# 1.055551290512085
# 0.07634595639870069
# 9
# [15, 10, 3.0] dual hidden layers plus quadratic
# 0.9029049873352051
# 0.17471145676679598
# 92
# [15, 10, 5.0] single hidden layer plus cross-entropy
# 0.26065564155578613
# 0.13956412146835087
# 80
# [15, 10, 5.0] single hidden layer plus quadratic
# 0.29718971252441406
# 0.17647797667528659
# 59
# [15, 10, 5.0] dual hidden layers plus cross-entropy
# 0.4476501941680908
# 0.19210412867532312
# 33
# [15, 10, 5.0] dual hidden layers plus quadratic
# 0.4492945671081543
# 0.10137702731327103
# 65
# [15, 20, 0.1] single hidden layer plus cross-entropy
# 0.24423527717590332
# 0.11530710227706177
# 79
# [15, 20, 0.1] single hidden layer plus quadratic
# 0.30845117568969727
# 0.16126203917281273
# 85
# [15, 20, 0.1] dual hidden layers plus cross-entropy
# 0.4429347515106201
# 0.1350471050473908
# 25
# [15, 20, 0.1] dual hidden layers plus quadratic
# 0.6300947666168213
# 0.20474172463469686
# 93
# [15, 20, 0.5] single hidden layer plus cross-entropy
# 0.688654899597168
# 0.11092397166505014
# 35
# [15, 20, 0.5] single hidden layer plus quadratic
# 0.7613179683685303
# 0.1335926648664855
# 48
# [15, 20, 0.5] dual hidden layers plus cross-entropy
# 1.5108139514923096
# 0.14282291365980354
# 20
# [15, 20, 0.5] dual hidden layers plus quadratic
# 1.7181189060211182
# 0.1377339800092827
# 79
# [15, 20, 1.0] single hidden layer plus cross-entropy
# 0.9638738632202148
# 0.11978650140734043
# 11
# [15, 20, 1.0] single hidden layer plus quadratic
# 0.5725512504577637
# 0.18135650307898354
# 65
# [15, 20, 1.0] dual hidden layers plus cross-entropy
# 0.5067014694213867
# 0.12715469363266463
# 33
# [15, 20, 1.0] dual hidden layers plus quadratic
# 0.4876289367675781
# 0.13459118356470653
# 48
# [15, 20, 3.0] single hidden layer plus cross-entropy
# 0.26732945442199707
# 0.11751347738201016
# 46
# [15, 20, 3.0] single hidden layer plus quadratic
# 0.30166053771972656
# 0.13421056140249668
# 35
# [15, 20, 3.0] dual hidden layers plus cross-entropy
# 0.45638489723205566
# 0.10898495309669728
# 61
# [15, 20, 3.0] dual hidden layers plus quadratic
# 0.4609200954437256
# 0.13747860960820432
# 61
# [15, 20, 5.0] single hidden layer plus cross-entropy
# 0.2782328128814697
# 0.12492631055399163
# 56
# [15, 20, 5.0] single hidden layer plus quadratic
# 0.2789268493652344
# 0.16847736205696887
# 11
# [15, 20, 5.0] dual hidden layers plus cross-entropy
# 0.48592400550842285
# 0.128989512818924
# 73
# [15, 20, 5.0] dual hidden layers plus quadratic
# 0.4778721332550049
# 0.12448229841350696
# 44
# [15, 100, 0.1] single hidden layer plus cross-entropy
# 0.2659015655517578
# 0.15353876416158999
# 97
# [15, 100, 0.1] single hidden layer plus quadratic
# 0.2967994213104248
# 0.637274131036912
# 93
# [15, 100, 0.1] dual hidden layers plus cross-entropy
# 0.451397180557251
# 0.16631598591837474
# 93
# [15, 100, 0.1] dual hidden layers plus quadratic
# 0.46534252166748047
# 0.5064317771709188
# 25
# [15, 100, 0.5] single hidden layer plus cross-entropy
# 0.257979154586792
# 0.13017600455445816
# 51
# [15, 100, 0.5] single hidden layer plus quadratic
# 0.29297518730163574
# 0.15271605655353818
# 95
# [15, 100, 0.5] dual hidden layers plus cross-entropy
# 0.43746352195739746
# 0.1342853074982913
# 20
# [15, 100, 0.5] dual hidden layers plus quadratic
# 0.8878278732299805
# 0.17489019168357123
# 93
# [15, 100, 1.0] single hidden layer plus cross-entropy
# 0.5414478778839111
# 0.1293137794195487
# 82
# [15, 100, 1.0] single hidden layer plus quadratic
# 0.6012768745422363
# 0.13240390680927777
# 25
# [15, 100, 1.0] dual hidden layers plus cross-entropy
# 0.67319655418396
# 0.13562551680021512
# 50
# [15, 100, 1.0] dual hidden layers plus quadratic
# 0.4757540225982666
# 0.1471112851937915
# 25
# [15, 100, 3.0] single hidden layer plus cross-entropy
# 0.27169036865234375
# 0.12144215759937185
# 53
# [15, 100, 3.0] single hidden layer plus quadratic
# 0.2970883846282959
# 0.14758903257123868
# 20
# [15, 100, 3.0] dual hidden layers plus cross-entropy
# 0.46883416175842285
# 0.1273448817064697
# 1
# [15, 100, 3.0] dual hidden layers plus quadratic
# 0.4903221130371094
# 0.1359067429917174
# 25
# [15, 100, 5.0] single hidden layer plus cross-entropy
# 0.24648666381835938
# 0.2282136961029439
# 40
# [15, 100, 5.0] single hidden layer plus quadratic
# 0.30762362480163574
# 0.14216853158149498
# 36
# [15, 100, 5.0] dual hidden layers plus cross-entropy
# 0.4480412006378174
# 0.14266037110891824
# 67
# [15, 100, 5.0] dual hidden layers plus quadratic
# 0.48990797996520996
# 0.14075319123164623
# 64
# [30, 5, 0.1] single hidden layer plus cross-entropy
# 0.5239644050598145
# 0.08782581440328795
# 59
# [30, 5, 0.1] single hidden layer plus quadratic
# 0.6091010570526123
# 0.14855364051011036
# 82
# [30, 5, 0.1] dual hidden layers plus cross-entropy
# 0.9379119873046875
# 0.12363600885959002
# 53
# [30, 5, 0.1] dual hidden layers plus quadratic
# 0.98785400390625
# 0.1347486762524914
# 93
# [30, 5, 0.5] single hidden layer plus cross-entropy
# 0.6011497974395752
# 0.05950637094697822
# 34
# [30, 5, 0.5] single hidden layer plus quadratic
# 1.929307222366333
# 0.13108840807056388
# 11
# [30, 5, 0.5] dual hidden layers plus cross-entropy
# 1.3931605815887451
# 0.034949531990354804
# 11
# [30, 5, 0.5] dual hidden layers plus quadratic
# 0.9785077571868896
# 0.14137616656114932
# 26
# [30, 5, 1.0] single hidden layer plus cross-entropy
# 0.5365819931030273
# 0.022365904025364418
# 59
# [30, 5, 1.0] single hidden layer plus quadratic
# 0.6513009071350098
# 0.0871052169515379
# 97
# [30, 5, 1.0] dual hidden layers plus cross-entropy
# 0.9522011280059814
# 0.12574930628238842
# 59
# [30, 5, 1.0] dual hidden layers plus quadratic
# 0.9789950847625732
# 0.15452855225524145
# 43
# [30, 5, 3.0] single hidden layer plus cross-entropy
# 0.5686337947845459
# 0.02013717410070714
# 88
# [30, 5, 3.0] single hidden layer plus quadratic
# 0.6102397441864014
# 0.1612289594916739
# 66
# [30, 5, 3.0] dual hidden layers plus cross-entropy
# 0.9498939514160156
# 0.07604910782830945
# 44
# [30, 5, 3.0] dual hidden layers plus quadratic
# 1.5960338115692139
# 0.17692061958398866
# 11
# [30, 5, 5.0] single hidden layer plus cross-entropy
# 2.3511545658111572
# 0.3277710300124857
# 65
# [30, 5, 5.0] single hidden layer plus quadratic
# 1.7591156959533691
# 0.11959297867156063
# 8
# [30, 5, 5.0] dual hidden layers plus cross-entropy
# 2.34394907951355
# 0.14142599859090005
# 25
# [30, 5, 5.0] dual hidden layers plus quadratic
# 2.3675434589385986
# 0.17705825412131299
# 66
# [30, 10, 0.1] single hidden layer plus cross-entropy
# 0.5148701667785645
# 0.12720737666329932
# 61
# [30, 10, 0.1] single hidden layer plus quadratic
# 0.6169073581695557
# 0.14357958225091835
# 16
# [30, 10, 0.1] dual hidden layers plus cross-entropy
# 1.795377254486084
# 0.12993985777267042
# 82
# [30, 10, 0.1] dual hidden layers plus quadratic
# 1.837350606918335
# 0.1368855746127072
# 20
# [30, 10, 0.5] single hidden layer plus cross-entropy
# 0.554276704788208
# 0.0673645349592198
# 59
# [30, 10, 0.5] single hidden layer plus quadratic
# 0.5768582820892334
# 0.17131477527152134
# 60
# [30, 10, 0.5] dual hidden layers plus cross-entropy
# 0.9739301204681396
# 0.12668808929051534
# 11
# [30, 10, 0.5] dual hidden layers plus quadratic
# 0.9859318733215332
# 0.13992275248590172
# 61
# [30, 10, 1.0] single hidden layer plus cross-entropy
# 0.5226125717163086
# 0.04069596271164064
# 84
# [30, 10, 1.0] single hidden layer plus quadratic
# 0.5672817230224609
# 0.1845256076843276
# 11
# [30, 10, 1.0] dual hidden layers plus cross-entropy
# 0.9037926197052002
# 0.05013552828190834
# 44
# [30, 10, 1.0] dual hidden layers plus quadratic
# 1.4761505126953125
# 0.13767626552197837
# 64
# [30, 10, 3.0] single hidden layer plus cross-entropy
# 1.7899501323699951
# 0.13614515386260495
# 65
# [30, 10, 3.0] single hidden layer plus quadratic
# 1.340101957321167
# 0.08106814590990451
# 66
# [30, 10, 3.0] dual hidden layers plus cross-entropy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-475e31e0b5cc> in <module>
#      51   start = time.time()
#      52   net2 = Network([784,30,15,10])
# ---> 53   accuracies.append(net2.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
#      54   finish = time.time()
#      55   elapsed = finish - start
#
# /content/nn3/src/network2.py in SGD(self, training_data, epochs, mini_batch_size, eta, lmbda, evaluation_data, monitor_evaluation_cost, monitor_evaluation_accuracy, monitor_training_cost, monitor_training_accuracy)
#     163                 for k in range(0, n, mini_batch_size)]
#     164             for mini_batch in mini_batches:
# --> 165                 self.update_mini_batch(
#     166                     mini_batch, eta, lmbda, len(training_data))
#     167 #            print(f"Epoch {j} training complete")
#
# /content/nn3/src/network2.py in update_mini_batch(self, mini_batch, eta, lmbda, n)
#     197         nabla_w = [np.zeros(w.shape) for w in self.weights]
#     198         for x, y in mini_batch:
# --> 199             delta_nabla_b, delta_nabla_w = self.backprop(x, y)
#     200             nabla_b = [nb+dnb for nb, dnb in zip(nabla_b, delta_nabla_b)]
#     201             nabla_w = [nw+dnw for nw, dnw in zip(nabla_w, delta_nabla_w)]
#
# /content/nn3/src/network2.py in backprop(self, x, y)
#     217         zs = [] # list to store all the z vectors, layer by layer
#     218         for b, w in zip(self.biases, self.weights):
# --> 219             z = np.dot(w, activation)+b
#     220             zs.append(z)
#     221             activation = sigmoid(z)
#
# KeyboardInterrupt:

# %%
# finds the image that the network has the hardest time classifying
def findTroublesomeImage(test_data):
    return np.argmin([np.max(net.feedforward(x)) for x, _ in test_data])

# %%
ii = findTroublesomeImage(test_data)
import matplotlib.pyplot as plt
plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")

# %%
import matplotlib.pyplot as plt

# pre-process our really janked up data ... first the training_times
training_timesSingle1 = training_times[0::4]
training_timesSingle2 = training_times[1::4]
training_timesDouble1 = training_times[2::4]
training_timesDouble2 = training_times[3::4]
training_timesSingle = []
training_timesDouble = []
for tt1, tt2 in zip(training_timesSingle1, training_timesSingle2):
    training_timesSingle.append(tt1)
    training_timesSingle.append(tt2)
for tt1, tt2 in zip(training_timesDouble1, training_timesDouble2):
    training_timesDouble.append(tt1)
    training_timesDouble.append(tt2)

# and now the accuracies...
accuraciesSingle1 = accuracies[0::4]
accuraciesSingle2 = accuracies[1::4]
accuraciesDouble1 = accuracies[2::4]
accuraciesDouble2 = accuracies[3::4]
accuraciesSingle = []
accuraciesDouble = []
for acc1, acc2 in zip(accuraciesSingle1, accuraciesSingle2):
    accuraciesSingle.append(acc1[1][-1])
    accuraciesSingle.append(acc2[1][-1])
for acc1, acc2 in zip(accuraciesDouble1, accuraciesDouble2):
    accuraciesDouble.append(acc1[1][-1])
    accuraciesDouble.append(acc2[1][-1])

# and now the labels
labelsSingle = []
labelsDouble = []
for config in configs:
    labelsSingle.append(f"{config}-cross-784-15-10")
    labelsSingle.append(f"{config}-quad-784-15-10")
    labelsDouble.append(f"{config}-cross-784-30-15-10")
    labelsDouble.append(f"{config}-quad-784-30-15-10")

fig, ax = plt.subplots(figsize=(50,10))
ax.plot(labelsSingle, accuraciesSingle)
plt.show()
fig, ax = plt.subplots(figsize=(50,10))
ax.plot(labelsDouble, training_timesDouble)
plt.show()

# %%
# extract the "results" (training times and accuracies) for all configs where the # epochs is 30, the batch size is 10, the cost function is quadratic and the learning rate is variable
label_learningrate = []
tt_learningrate = []
acc_learningrate = []
for i, config in enumerate(configs):
  if config[0] == 30 and config[1] == 10:
    label_learningrate.append(labelsSingle[2*i])
    tt_learningrate.append(training_timesSingle[2*i]) # 2i ... b/c we are storing two times for every config ... +1 b/c it's the second one that we want (i.e., the quadratic cost function)
    acc_learningrate.append(accuraciesSingle[2*i]) # 2i ... b/c we are storing two times for every config ... +1 b/c it's the second one that we want (i.e., the quadratic cost function)

print(label_learningrate)
print(tt_learningrate)
print(acc_learningrate)

plt.subplots(figsize=(20,6))
plt.plot(label_learningrate, tt_learningrate)
plt.show()
plt.subplots(figsize=(20,6))
plt.plot(label_learningrate, acc_learningrate)
plt.show
